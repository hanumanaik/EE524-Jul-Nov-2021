# %%
print('q1 answer')
print('q1 pdf and cdf graphs')
import matplotlib.pyplot as plt
x=[0,1,2]
y=[0,0.75,0.25]
plt.xlabel('X values')
plt.ylabel('PDF & CDF')
plt.plot(x,y,'g',label='PDF',linewidth=5)
a=[0,1,2]
b=[0,0.75,1]
plt.title('PDF & CDF GRAPHS')
plt.plot(a,b,'r',label='CDF',linewidth=5)
plt.legend()
# Out:
# q1
# q1 pdf and cdf graphs

# %%
print('beta distribution')
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import beta
#
# Set the shape paremeters
#
a, b = 80, 10
#
# Generate the value between
#
x = np.linspace(beta.ppf(0.01, a, b),beta.ppf(0.99, a, b), 100)
#
# Plot the beta distribution
#
plt.figure(figsize=(7,7))
plt.xlim(0.7, 1)
plt.plot(x, beta.pdf(x, a, b), 'r-')
plt.title('Beta Distribution', fontsize='15')
plt.xlabel('Values of Random Variable X (0, 1)', fontsize='15')
plt.ylabel('Probability', fontsize='15')
plt.show()
# Out:
# beta distribution

# %%
print('lambda')
def graph(func, x_range):
   x = np.arange(*x_range)
   y = func(x)
   plt.plot(x, y)

graph(lambda x: 100*(np.power(0.8, x)), (0,100))
# Out:
# lambda

# %%
print('gamma')
print('q1')
import numpy as np
import scipy.stats as stats
from matplotlib import pyplot as plt

plt.rcParams["figure.figsize"] = [7.50, 3.50]
plt.rcParams["figure.autolayout"] = True

x = np.linspace(0, 10, 10)
y = stats.gamma.pdf(x, a=5, scale=0.333)

plt.plot(x, y, "ro-", label=(r'$\alpha=0, \beta=3$'))
plt.legend(loc='upper right')

plt.show()
# Out:
# gamma
# q1

# %%
print('discrete a answer')
print('mean and var values p=0.9')
p=0.9
c=0
d=0
for x in range(0,2):
    mean=x*p
    c=c+mean
    mean2=x**2*p
    d=d+mean2
var=d-c**2
print('mean value is:',mean,'var value is:',var)
p=0.5
# Out:
# discrete a answer
# mean and var values p=0.9
# mean value is: 0.9 var value is: 0.08999999999999997

# %%
print('discrete a answer')
print('mean and var values p=0.5')
p=0.5
c=0
d=0
for x in range(0,2):
    mean=x*p
    c=c+mean
    mean2=x**2*p
    d=d+mean2
var=d-c**2
print('mean value is:',mean,'var value is:',var)
p=0.5
# Out:
# discrete a answer
# mean and var values p=0.5
# mean value is: 0.5 var value is: 0.25

# %%
print('discrete a answer')
print('mean and var values p=0.2')
p=0.2
c=0
d=0
for x in range(0,2):
    mean=x*p
    c=c+mean
    mean2=x**2*p
    d=d+mean2
var=d-c**2
print('mean value is:',mean,'var value is:',var)
p=0.5
# Out:
# discrete a answer
# mean and var values p=0.2
# mean value is: 0.2 var value is: 0.16

# %%
print('discontinous a sol')
from matplotlib import pyplot as plt
x=[0,1]
y=[0.5,0.5]
plt.xlabel('X values')
plt.ylabel('probability')
plt.title('PMF PLOT')
plt.stem(x,y)
print('mean is 0.9')
print('var is 0.09')
# Out:
# discontinous a sol
# mean is 0.9
# var is 0.09

# %%
print('discrete b answer')
from scipy.stats import binom
import matplotlib.pyplot as plt
n=20
p=0.6
x=range(0,n)#0,1,2.....n-1
pmf=binom.pmf(x,n,p)
print(pmf)
mean,var=binom.stats(n,p,moments='mv')
print(mean,var)
plt.xlabel('X values')
plt.ylabel('PMF')
plt.title('PMF PLOT')
plt.stem(x,pmf)
# Out:
# discrete b answer
# [1.09951163e-08 3.29853488e-07 4.70041221e-06 4.23037099e-05
#  2.69686150e-04 1.29449352e-03 4.85435071e-03 1.45630521e-02
#  3.54974396e-02 7.09948791e-02 1.17141551e-01 1.59738478e-01
#  1.79705788e-01 1.65882266e-01 1.24411699e-01 7.46470195e-02
#  3.49907904e-02 1.23496907e-02 3.08742268e-03 4.87487792e-04]
# 12.0 4.800000000000001
# <StemContainer object of 3 artists>

# %%
print('discrete c answer')
from scipy.stats import binom
import matplotlib.pyplot as plt
n=5#lets take k is 5
p=0.5# p is probability
x=range(0,n)#0,1....n-1 i.e., 5
pmf=binom.pmf(x,n,p)
print(pmf)
mean,var=binom.stats(n,p,moments='mv')
print(mean,var)
plt.xlabel('X values')
plt.ylabel('PMF')
plt.title('PMF PLOT')
plt.stem(x,pmf)
# Out:
# discrete c answer
# [0.03125 0.15625 0.3125  0.3125  0.15625]
# 2.5 1.25
# <StemContainer object of 3 artists>
